# %% [markdown]
# # Python Exercise-9 (Exploratory data analysis)

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('D:\Shivam\Python Ex\EX-9\cities_air_quality_water_pollution.18-10-2021.csv')

# %%
print(df.shape)
print('-'*120)
df.head()
# Out:
# (3963, 5)
# ------------------------------------------------------------------------------------------------------------------------
#                City                 "Region"                    "Country"  \
# 0     New York City               "New York"   "United States of America"
# 1  Washington, D.C.   "District of Columbia"   "United States of America"
# 2     San Francisco             "California"   "United States of America"
# 3            Berlin                       ""                    "Germany"
# 4       Los Angeles             "California"   "United States of America"
#
#     "AirQuality"   "WaterPollution"
# 0      46.816038          49.504950
# 1      66.129032          49.107143
# 2      60.514019          43.000000
# 3      62.364130          28.612717
# 4      36.621622          61.299435

# %%
#checking duplicacy
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [City,  "Region",  "Country",  "AirQuality",  "WaterPollution"]
# Index: []

# %%
#checking missing values
df.isnull().sum()
# Out:
# City                 0
#  "Region"            0
#  "Country"           0
#  "AirQuality"        0
#  "WaterPollution"    0
# dtype: int64

# %%
df.isin(['-']).sum()
# Out:
# City                 0
#  "Region"            0
#  "Country"           0
#  "AirQuality"        0
#  "WaterPollution"    0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df.columns = df.columns.str.replace('"','')

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %% [markdown]
# ## 1. Which cities have the highest and lowest air quality?

# %%
print('Cities have the highest air quality: ')
print('-'*120)
df[df['AirQuality'] == df['AirQuality'].max()]['City'].tolist()
# Out:
# Cities have the highest air quality:
# ------------------------------------------------------------------------------------------------------------------------
# ['Vaduz',
#  'Pskov',
#  'Veliky Novgorod',
#  'Lübeck',
#  'Hagen',
#  'Ingolstadt',
#  'Recklinghausen',
#  'Kursk',
#  'Cottbus',
#  'Zadar',
#  'Sibenik',
#  'Gera',
#  'Minden',
#  'Wilhelmshaven',
#  'Wesel',
#  'Neu-Ulm',
#  'Riehen',
#  'Rovinj',
#  'Yoshkar-Ola',
#  'Koprivnica',
#  'Bjelovar',
#  'Mary',
#  'Pematangsiantar',
#  'Soest',
#  'Nordhausen',
#  'Girona',
#  'Amberg',
#  'Bad Kreuznach',
#  'Burgos',
#  'Pamplona',
#  'Magelang',
#  'Lugo',
#  'Madiun',
#  'Mojokerto',
#  'Ronda',
#  'Banjarmasin',
#  'Palangkaraya',
#  'Kaufbeuren',
#  'Coburg',
#  'Saarlouis',
#  'Bernburg',
#  'Backnang',
#  'Kendari',
#  'Caceres',
#  'Grosuplje',
#  'Slovenska Bistrica',
#  'Skofja Loka',
#  'Uelzen',
#  'Maldonado',
#  'Welwyn Garden City',
#  'Neustrelitz',
#  'Skovde',
#  'Landstuhl',
#  'Kalmar',
# ...

# %%
print('Cities have the lowest air quality: ')
print('-'*120)
df[df['AirQuality'] == df['AirQuality'].min()]['City'].tolist()
# Out:
# Cities have the lowest air quality:
# ------------------------------------------------------------------------------------------------------------------------
# ['Abakan',
#  'Busto Arsizio',
#  'Cherepovets',
#  'Ryazan',
#  'Coyhaique',
#  'Bangui',
#  'Rancagua',
#  'Saransk',
#  'Tanjung Pinang',
#  'Linares',
#  'Laredo',
#  'Nausori',
#  'Zunyi',
#  'Jinzhou',
#  'Zigong',
#  'Liuzhou',
#  'Gwangyang',
#  'Icheon',
#  'Pyeongtaek',
#  'Shaoxing',
#  'Kandahar',
#  'Puente Alto',
#  'San Fernando',
#  'Lianyungang',
#  'Suqian',
#  'Yancheng',
#  'Yangzhou',
#  'Taizhou',
#  'Jiaxing',
#  'Jinhua',
#  'Quzhou',
#  'Lishui',
#  'Shijiazhuang',
#  'Tangshan',
#  'Qinhuangdao',
#  'Xingtai',
#  'Zhangjiakou',
#  'Chengde',
#  'Cangzhou',
#  'Langfang',
#  'Hengshui',
#  'Zalaegerszeg',
#  'Taicang',
#  'Abadan',
#  'Zhangzhou',
#  'Shiyan',
#  'Jingzhou',
#  'Yichang',
#  'Huanggang',
#  'Taiyuan',
#  'Yangquan',
#  'Changzhi',
#  'Jincheng',
#  'Jinzhong',
#  'Xinzhou',
# ...

# %% [markdown]
# ## 3. Are there any correlations between air quality and water pollution levels?

# %%
print('Correlation between air quality and water pollution: ',df['AirQuality'].corr(df['WaterPollution']))
print('-'*120)
sns.heatmap(df[['AirQuality','WaterPollution']].corr(),annot=True)
plt.show()
# Out:
# Correlation between air quality and water pollution:  -0.45417262259278224
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 4. Which cities have the highest and lowest water pollution levels?

# %%
print('Cities have the highest WaterPollution: ')
print('-'*120)
df[df['AirQuality'] == df['WaterPollution'].max()]['City'].tolist()
# Out:
# Cities have the highest WaterPollution:
# ------------------------------------------------------------------------------------------------------------------------
# ['Vaduz',
#  'Pskov',
#  'Veliky Novgorod',
#  'Lübeck',
#  'Hagen',
#  'Ingolstadt',
#  'Recklinghausen',
#  'Kursk',
#  'Cottbus',
#  'Zadar',
#  'Sibenik',
#  'Gera',
#  'Minden',
#  'Wilhelmshaven',
#  'Wesel',
#  'Neu-Ulm',
#  'Riehen',
#  'Rovinj',
#  'Yoshkar-Ola',
#  'Koprivnica',
#  'Bjelovar',
#  'Mary',
#  'Pematangsiantar',
#  'Soest',
#  'Nordhausen',
#  'Girona',
#  'Amberg',
#  'Bad Kreuznach',
#  'Burgos',
#  'Pamplona',
#  'Magelang',
#  'Lugo',
#  'Madiun',
#  'Mojokerto',
#  'Ronda',
#  'Banjarmasin',
#  'Palangkaraya',
#  'Kaufbeuren',
#  'Coburg',
#  'Saarlouis',
#  'Bernburg',
#  'Backnang',
#  'Kendari',
#  'Caceres',
#  'Grosuplje',
#  'Slovenska Bistrica',
#  'Skofja Loka',
#  'Uelzen',
#  'Maldonado',
#  'Welwyn Garden City',
#  'Neustrelitz',
#  'Skovde',
#  'Landstuhl',
#  'Kalmar',
# ...

# %%
print('Cities have the lowest WaterPollution: ')
print('-'*120)
df[df['AirQuality'] == df['WaterPollution'].min()]['City'].tolist()
# Out:
# Cities have the lowest WaterPollution:
# ------------------------------------------------------------------------------------------------------------------------
# ['Abakan',
#  'Busto Arsizio',
#  'Cherepovets',
#  'Ryazan',
#  'Coyhaique',
#  'Bangui',
#  'Rancagua',
#  'Saransk',
#  'Tanjung Pinang',
#  'Linares',
#  'Laredo',
#  'Nausori',
#  'Zunyi',
#  'Jinzhou',
#  'Zigong',
#  'Liuzhou',
#  'Gwangyang',
#  'Icheon',
#  'Pyeongtaek',
#  'Shaoxing',
#  'Kandahar',
#  'Puente Alto',
#  'San Fernando',
#  'Lianyungang',
#  'Suqian',
#  'Yancheng',
#  'Yangzhou',
#  'Taizhou',
#  'Jiaxing',
#  'Jinhua',
#  'Quzhou',
#  'Lishui',
#  'Shijiazhuang',
#  'Tangshan',
#  'Qinhuangdao',
#  'Xingtai',
#  'Zhangjiakou',
#  'Chengde',
#  'Cangzhou',
#  'Langfang',
#  'Hengshui',
#  'Zalaegerszeg',
#  'Taicang',
#  'Abadan',
#  'Zhangzhou',
#  'Shiyan',
#  'Jingzhou',
#  'Yichang',
#  'Huanggang',
#  'Taiyuan',
#  'Yangquan',
#  'Changzhi',
#  'Jincheng',
#  'Jinzhong',
#  'Xinzhou',
# ...

# %% [markdown]
# ## 5. Is there any relationship between air quality and water pollution in the dataset?

# %%
print('Yes','\n','-'*120)
print('Correlation between air quality and water pollution: ',df['AirQuality'].corr(df['WaterPollution']))
# Out:
# Yes
#  ------------------------------------------------------------------------------------------------------------------------
# Correlation between air quality and water pollution:  -0.45417262259278224
